# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel("/content/train.csv.xlsx")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.drop(["SibSp"],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  Parch  \
# 0                              Braund, Mr. Owen Harris    male  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={"Fare":"Price","Pclass":"Class"})
# Out:
#      PassengerId  Survived  Class  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
duplicate_rows_df=df[df.duplicated()]
print("number of duplicate values:",duplicate_rows_df.shape)
# Out:
# number of duplicate values: (0, 12)

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df["Age"].fillna(df["Age"])

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.dropna()

# %%
plt.plot(x="passengerId",y="survived",
xlabel="passengerlist",
ylabel="classlist",title="trainpassengers")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-4db0ae298d95> in <cell line: 0>()
# ----> 1 plt.plot(x="passengerId",y="survived",
#       2 xlabel="passengerlist",
#       3 ylabel="classlist",title="trainpassengers")
#       4 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Survived",data=df,palette="pastel")
plt.title("Survival count",fontsize=14)
plt.show()
# Out:
# <ipython-input-28-040c670c05a9>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Survived",data=df,palette="pastel")

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Sex",y="Survived",data=df,palette="mako")
plt.title("Survival count",fontsize=14)
plt.show()
# Out:
# <ipython-input-29-ac3237ad66ed>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Sex",y="Survived",data=df,palette="mako")

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"],bins=30,kde=True,color="blue")
plt.title("Age Distribution",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[["Age","Fare"]],palette="coolwarm")
plt.title("boxplot for Outlier Determination")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="Age",y="Fare",data=df,palette="muted")
plt.title("Age vs Fare",fontsize=14)
plt.show()
# Out:
# <ipython-input-33-05fae1f280ea>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="Age",y="Fare",data=df,palette="muted")

# %%
plt.figure(figsize=(6,4))
sns.violinplot(x="Pclass",y="Age",data=df,palette="pastel")
plt.title("class vs age",fontsize=14)
plt.show()
# Out:
# <ipython-input-34-e78091c33c8f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Pclass",y="Age",data=df,palette="pastel")

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data=df,x="Fare",color="red")
plt.title("Fare distribution",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x="PassengerId",y="Fare",data=df)
plt.title("PassengerId vs Fare",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.pie(x="Pclass",data=df)
plt.title("Pclass Distribution")
plt.show()
